# %% [markdown]
# <a href="https://colab.research.google.com/github/sarah-schayder/proc-imagens/blob/main/banco_imgs_nivel_cinza_proc_img_25_2_sarah_schayder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import skimage as ski
import os
from natsort import natsorted, ns
import matplotlib.pyplot as plt

# %%
caminho = "/content/drive/MyDrive/processamento de imagens/banco-imgs-original/"

# %%
list_files = os.listdir("/content/drive/MyDrive/processamento de imagens/banco-imgs-original/")
list_files.sort()
list_files
# Out:
# ['chave_i_d_sarah.jpg',
#  'chave_i_n_sarah.jpg',
#  'chave_o_d_sarah.jpg',
#  'chave_o_n_sarah.jpg',
#  'escova_i_d_sarah.jpg',
#  'escova_i_n_sarah.jpg',
#  'escova_o_d_sarah.jpg',
#  'escova_o_n_sarah.jpg',
#  'flor_i_d_sarah.jpg',
#  'flor_i_n_sarah.jpg',
#  'flor_o_d_sarah.jpg',
#  'flor_o_n_sarah.jpg']

# %%
image_list = []
for filename in list_files:
  image_list.append(ski.io.imread(caminho + filename))

# %%
caminho2 = "/content/drive/MyDrive/processamento de imagens/nivel-de-cinza/"

# %%
for filename, image in zip(list_files, image_list):
  gray_image = ski.color.rgb2gray(image)
  ski.io.imsave(caminho2 + 'cinza_' + filename, ski.util.img_as_ubyte(gray_image))
  plt.imshow(gray_image, cmap='gray')
  plt.show()
